# %% [markdown]
# # 03 - Model Development & Evaluation
# Elvara Health | Early Sepsis Warning & Deterioration System
#
# Trains `HistGradientBoostingClassifier` (Primary) vs `LogisticRegression` (Baseline),
# evaluates classification metrics, and exports trained model artifacts.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.train import train_and_evaluate_models

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Train & Evaluate Models

# %%
metadata = train_and_evaluate_models()
print('Training complete! Metadata:', metadata)
